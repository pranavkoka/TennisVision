# %%
from ultralytics import YOLO
from pathlib import Path
import cv2
import time

input_image = Path(r'input\cv_image.png')
output_dir = Path("diff_models_output")
models = ["yolov8n.pt", "yolov8s.pt", "yolov8m.pt", "yolov8l.pt", "yolov8x.pt", "yolo26n.pt", "yolo26s.pt", "yolo26m.pt", "yolo26l.pt", "yolo26x.pt"]
output_dir.mkdir(parents=True, exist_ok=True)

# %%
for model_name in models:

    print(f"\nRunning {model_name}...")
    model = YOLO(model_name)
    results = model.predict(
        source=str(input_image),
        verbose=False #doesn't give all the detailed terminal output
        )

    annotated_image = results[0].plot()
    model_short_name = Path(model_name).stem #.stem removes the .pt
    output_filename = f"{model_short_name}_{input_image.stem}.jpg"
    output_path = output_dir / output_filename
    cv2.imwrite(str(output_path), annotated_image)
    print(f"Saved: {output_path}")

print("\nDone!")
# Out:
# Running yolov8n.pt...
# Saved: diff_models_output\yolov8n_cv_image.jpg
#
# Running yolov8s.pt...
# Saved: diff_models_output\yolov8s_cv_image.jpg
#
# Running yolov8m.pt...
# Saved: diff_models_output\yolov8m_cv_image.jpg
#
# Running yolov8l.pt...
# Saved: diff_models_output\yolov8l_cv_image.jpg
#
# Running yolov8x.pt...
# Saved: diff_models_output\yolov8x_cv_image.jpg
#
# Running yolo26n.pt...
# Saved: diff_models_output\yolo26n_cv_image.jpg
#
# Running yolo26s.pt...
# Saved: diff_models_output\yolo26s_cv_image.jpg
#
# Running yolo26m.pt...
# Saved: diff_models_output\yolo26m_cv_image.jpg
#
# Running yolo26l.pt...
# Saved: diff_models_output\yolo26l_cv_image.jpg
#
# Running yolo26x.pt...
# Saved: diff_models_output\yolo26x_cv_image.jpg
#
# Done!

# %%
WARMUP_RUNS = 5
BENCHMARK_RUNS = 30

for model_name in models:

    print(f"\nRunning {model_name}...")

    model = YOLO(model_name)

    # -------------------------
    # Warm-up
    # -------------------------
    for _ in range(WARMUP_RUNS):
        model.predict(
            source=str(input_image),
            verbose=False
        )

    # -------------------------
    # Benchmark
    # -------------------------
    times = []

    for _ in range(BENCHMARK_RUNS):

        start = time.perf_counter()

        results = model.predict(
            source=str(input_image),
            verbose=False
        )

        elapsed = time.perf_counter() - start
        times.append(elapsed)

    # -------------------------
    # Calculate average
    # -------------------------
    average_time = sum(times) / len(times)

    print(
        f"{model_name}: "
        f"{average_time:.4f} seconds average"
    )

print("\nDone once")

for model_name in models:

    print(f"\nRunning {model_name}...")

    model = YOLO(model_name)

    # -------------------------
    # Warm-up
    # -------------------------
    for _ in range(WARMUP_RUNS):
        model.predict(
            source=str(input_image),
            verbose=False
        )

    # -------------------------
    # Benchmark
    # -------------------------
    times = []

    for _ in range(BENCHMARK_RUNS):

        start = time.perf_counter()

        results = model.predict(
            source=str(input_image),
            verbose=False
        )

        elapsed = time.perf_counter() - start
        times.append(elapsed)

    # -------------------------
    # Calculate average
    # -------------------------
    average_time = sum(times) / len(times)

    print(
        f"{model_name}: "
        f"{average_time:.4f} seconds average"
    )

print("\nDone twice")
# Out:
# Running yolov8n.pt...
# yolov8n.pt: 0.0952 seconds average
#
# Running yolov8s.pt...
# yolov8s.pt: 0.0671 seconds average
#
# Running yolov8m.pt...
# yolov8m.pt: 0.0937 seconds average
#
# Running yolov8l.pt...
# yolov8l.pt: 0.0944 seconds average
#
# Running yolov8x.pt...
# yolov8x.pt: 0.1080 seconds average
#
# Running yolo26n.pt...
# yolo26n.pt: 0.0641 seconds average
#
# Running yolo26s.pt...
# yolo26s.pt: 0.0708 seconds average
#
# Running yolo26m.pt...
# yolo26m.pt: 0.0788 seconds average
#
# Running yolo26l.pt...
# yolo26l.pt: 0.0857 seconds average
#
# Running yolo26x.pt...
# yolo26x.pt: 0.0861 seconds average
#
# Done once
#
# Running yolov8n.pt...
# yolov8n.pt: 0.0654 seconds average
#
# Running yolov8s.pt...
# yolov8s.pt: 0.1004 seconds average
#
# Running yolov8m.pt...
# yolov8m.pt: 0.0851 seconds average
#
# Running yolov8l.pt...
# yolov8l.pt: 0.0903 seconds average
#
# Running yolov8x.pt...
# yolov8x.pt: 0.1008 seconds average
#
# Running yolo26n.pt...
# ...

# %%
model = YOLO('yolo26x')
model.predict('input/cv_video_input.mp4',save=True) #saved as predict-3
# Out:
# WARNING
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/214) c:\Users\Pranav Koka\Desktop\python_projects\TennisVision\input\cv_video_input.mp4: 384x640 6 persons, 1 tennis racket, 1 clock, 38.7ms
# video 1/1 (frame 2/214) c:\Users\Pranav Koka\Desktop\python_projects\TennisVision\input\cv_video_input.mp4: 384x640 6 persons, 1 tennis racket, 1 clock, 37.9ms
# ...

# %%
model = YOLO('models/yolo_last.pt')
model.predict('input/cv_video_input.mp4', conf=0.2, save=True)
# Out:
# WARNING
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/214) c:\Users\Pranav Koka\Desktop\python_projects\TennisVision\input\cv_video_input.mp4: 384x640 (no detections), 27.2ms
# video 1/1 (frame 2/214) c:\Users\Pranav Koka\Desktop\python_projects\TennisVision\input\cv_video_input.mp4: 384x640 1 tennis ball, 27.3ms
# video 1/1 (frame 3/214) c:\Users\Pranav Koka\Desktop\python_projects\TennisVision\input\cv_video_input.mp4: 384x640 2 tennis balls, 26.6ms
# ...

# %%
model = YOLO('yolo26x')
model.track('input/cv_video_input.mp4',save=True)
# Out:
# WARNING
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/214) c:\Users\Pranav Koka\Desktop\python_projects\TennisVision\input\cv_video_input.mp4: 384x640 1 person, 38.2ms
# video 1/1 (frame 2/214) c:\Users\Pranav Koka\Desktop\python_projects\TennisVision\input\cv_video_input.mp4: 384x640 1 person, 38.8ms
# video 1/1 (frame 3/214) c:\Users\Pranav Koka\Desktop\python_projects\TennisVision\input\cv_video_input.mp4: 384x640 1 person, 38.1ms
# ...
