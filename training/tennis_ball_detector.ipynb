# %% [markdown]
# Run this notebook in collab after doing the necessary pip installs

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="API KEY")
project = rf.workspace("viren-dhanwani").project("tennis-ball-detection")
version = project.version(6)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to tennis-ball-detection-6 in yolov5pytorch:: 100%|██████████| 1168/1168 [00:01<00:00, 782.23it/s]

# %%
import shutil

# %%
shutil.move(r"tennis-ball-detection-6\train",r"tennis-ball-detection-6\tennis-ball-detection-6\train")
shutil.move(r"tennis-ball-detection-6\test",r"tennis-ball-detection-6\tennis-ball-detection-6\test")
shutil.move(r"tennis-ball-detection-6\valid",r"tennis-ball-detection-6\tennis-ball-detection-6\valid")
# Out:
# 'tennis-ball-detection-6\\tennis-ball-detection-6\\valid'

# %%
# !yolo task=detect mode=train model=yolov5l6u.pt data="C:/Users/Pranav Koka/Desktop/python_projects/TennisVision/training/tennis-ball-detection-6/data.yaml" epochs=100 imgsz=640

# %%
dataset.location
# Out:
# 'c:\\Users\\Pranav Koka\\Desktop\\python_projects\\TennisVision\\training\\tennis-ball-detection-6'

# %% [markdown]
# Use one of the two models (preferably last.pt) that you can find in runs in training after running the above code in colab
